# %% [markdown]
# # Visualization 1

# %% [markdown]
# Dataset used: Deaths of Shelter Residents
# https://open.toronto.ca/dataset/deaths-of-shelter-residents/

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
df = pd.read_csv("/Users/charissachan/Desktop/DSI/visualization/02_activities/assignments/assigment_3_files/Deaths of Shelter Residents.csv")
df
# Out:
#      _id  Year Month  Total decedents  Male  Female  \
# 0      1  2007   Jan                0     0       0
# 1      2  2007   Feb                3     3       0
# 2      3  2007   Mar                3     2       1
# 3      4  2007   Apr                1     1       0
# 4      5  2007   May                2     2       0
# ..   ...   ...   ...              ...   ...     ...
# 227  228  2025   Dec                8     6       2
# 228  229  2026   Jan                4     3       1
# 229  230  2026   Feb                4     4       0
# 230  231  2026   Mar                3     2       1
# 231  232  2026   Apr                1     0       1
#
#      Transgender/Non-binary/Two-Spirit
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 227                                1.0
# 228                                0.0
# 229                                0.0
# 230                                0.0
# 231                                0.0
#
# [232 rows x 7 columns]

# %%
df_2010_2025 = df[(df["Year"] >= 2010) & (df["Year"] <= 2025)]

df_2010_2025
# Out:
#      _id  Year Month  Total decedents  Male  Female  \
# 36    37  2010   Jan                1     0       1
# 37    38  2010   Feb                1     1       0
# 38    39  2010   Mar                0     0       0
# 39    40  2010   Apr                0     0       0
# 40    41  2010   May                1     1       0
# ..   ...   ...   ...              ...   ...     ...
# 223  224  2025   Aug                4     2       2
# 224  225  2025   Sep                6     4       2
# 225  226  2025   Oct                3     2       1
# 226  227  2025   Nov                6     4       2
# 227  228  2025   Dec                8     6       2
#
#      Transgender/Non-binary/Two-Spirit
# 36                                 NaN
# 37                                 NaN
# 38                                 NaN
# 39                                 NaN
# 40                                 NaN
# ..                                 ...
# 223                                0.0
# 224                                0.0
# 225                                0.0
# 226                                0.0
# 227                                1.0
#
# [192 rows x 7 columns]

# %%
Yearly = df_2010_2025.groupby("Year", as_index=False)[["Male", "Female", "Total decedents"]].sum()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

x = Yearly["Year"]
y_male = Yearly["Male"]
y_female = Yearly["Female"]
y_total = Yearly["Total decedents"]
width = 0.4

ax.bar(x - 0.2, y_male, width, label="Male Deaths")
ax.bar(x + 0.2, y_female, width, label="Female Deaths")

ax.plot(x, y_total, marker="o", linewidth=2, label="Total Deaths")

ax.set_title("Deaths of Shelter Residents (2010–2025)")
ax.set_xlabel("Year")
ax.set_ylabel("Number of Deaths")


ax.set_xticks(x)
ax.set_xticklabels(x.astype(str), rotation=45)


ax.legend()

ax.margins(x=0.02)
ax.margins(y=0.1)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Resources Consulted:
# How to make a grouped bar chart:
# https://www.geeksforgeeks.org/python/create-a-grouped-bar-plot-in-matplotlib/
#
# How to set ticks:
# https://www.geeksforgeeks.org/python/matplotlib-setting-ticks-and-tick-labels/
