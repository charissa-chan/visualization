# %% [markdown]
# # June 15, 2026 Notes and Code

# %% [markdown]
# ### Activity" Three Elements of Persuasion
# - Rational Appeal
#     - uses specific numbers of people (quantitative data) to describe conditions on the
# - Moral Appeal
#     - schematics show humans crawling through the ship, which highlights inhuman conditions
#     - crammed conditions shown in image suggest it is unethical to treat people in that way
# - Emotional appeal
#     - language of legality induces strong feelings of injustic
#     - visualization evokes anger/provokes outrage

# %% [markdown]
# ### Data Visualization: Beyond Matplotlib

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scipy
import PIL
import requests

# %%
tips = sns.load_dataset("tips")
print(tips)
sns.set_style('dark')
tipgraph=sns.lineplot(data=tips,x='total_bill',y='tip',
                      color='hotpink',
                      linestyle='--',
                      linewidth=1,
                      marker='o',
                      markerfacecolor='indigo')
tipgraph.set(title='Tips vs. Total Bill',
             xlabel='Total Bill ($)',
             ylabel='Tip Amount ($)')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
tipgraph = sns.scatterplot(data=tips, x='total_bill',
                           y='tip', style='time', hue='day', palette=['purple',
                                                                      'hotpink', 'deepskyblue',
                                                                      'yellowgreen'])
tipgraph.set(title='Tips vs. Total Bill',
             xlabel='Total Bill ($)',
             ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
sns.pairplot(data = tips,hue = 'day')

# %%
daysplot = sns.relplot(data=tips,
                       x="total_bill",
                       y="tip",
                       hue="sex",
                       col="day",
                       kind="scatter",
                       col_wrap=2)

# %% [markdown]
# ### Activity: Comparing Data Visualizations
# How are they different? What does each visualization 'do'?
# - Left
#     - takes into account gender vs. sex
#     - small sample size
#     - see specific counts accurately
# - Right
#     - more interactive
#     - shows overal trend
#     - allows selection of vocabulary to get different conclusions
#     - uses larger data set
#
# What are the pros and cons of each?
# - Left
#     - smaller cognitive load
#     - simple descriptions, simple numbers -- more accurate to compare
#     - you do see overall trend, but less accurate (approximate numbers used)
#     - not much information you can extract
# - Right
#     - contains lots of stories
#     - more information, but easier to understand
#     - being interactive lets viewers target exactly what they are looking for
#     - allows freedom for audience
#     - allows subjective space (viewers can take away different things)
#     - colorcoded so easier to understand

# %% [markdown]
# ### Activity: Types of changes
# - not identity preserving, does not allow us to make direct comparisons (axes don't stay constant)
# - can exhibit immediate change or transitional change, depending on which words we try to explore together
# - spatial and retinal elements that stay constant:
#     - spatial positions change alot (points and frequencies all change)
#     - color stays constant; retinal elements stay constant
# - changes I might consider in redesigning:
#     - preserve the order of the y axis to allow for easier comparison between different snapshots

# %% [markdown]
# ### Data Visualization: Beyond Matplotlib (cont'd)

# %%
import plotly.graph_objects as go
from wordcloud import wordcloud
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# %%
x1 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

graph=go.Figure()
graph.add_trace(go.Bar(x=x1,y=y1))

graph.update_layout(title="Pirate Scores",
                    xaxis_title="Pirates",
                    yaxis_title="Score")


graph.write_html("02_activities/assignments/participation/pirategraph.html")

graph.show()

# %%
graph=go.Figure()
graph.add_trace(go.Scatter(x=x1,y=y1,mode="markers",marker=dict(size=15,color='hotpink',opacity=1,line=dict(width=5,color='purple'))))
graph.update_layout(title='Interactive Pirate Plot',
                    xaxis_title='Pirates',
                    yaxis_title='Scores',
                    width=500,
                    height=500)

# %%
from wordcloud import WordCloud
import pandas as pd # not covered in class, just for fun
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
on_bad_lines='skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# ...

# %%
df = pd.read_csv("02_activities/assignments/participation/movie_quotes.csv")
print(df)
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# ...

# %%
text="".join(each for each in df.quote)
wordcloud=WordCloud(background_color="white",colormap="inferno").generate(text)

fig,ax=plt.subplots(figsize=(7,3))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %%
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

diagram = venn2_unweighted([A,B],set_labels=('Fruits','Pies'),
                         set_colors=("blue","red"),
                         alpha=0.5)

diagram.get_label_by_id("10").set_text("\n".join(A - B))
diagram.get_label_by_id("11").set_text("\n".join(A & B))
diagram.get_label_by_id("01").set_text("\n".join(B - A))
