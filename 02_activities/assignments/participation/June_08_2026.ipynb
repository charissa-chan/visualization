# %% [markdown]
# # June 8, 2026 Notes and Code

# %% [markdown]
# ## Data Visualization: Customizing Our Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100, 50)
y2 = np.random.randint (0, 100, 50)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# /var/folders/jx/71mqbyqd6wgcxt7f5rbrwy9r0000gn/T/ipykernel_82087/3608551665.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc = 'lower right', 
        frameon = True,
        shadow = True,
        fontsize = 12,
        ncol = 2)
fig.show()
# Out:
# /var/folders/jx/71mqbyqd6wgcxt7f5rbrwy9r0000gn/T/ipykernel_82087/1415546649.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc = 'upper left', 
       bbox_to_anchor = (1, 1))
fig.show()
# Out:
# /var/folders/jx/71mqbyqd6wgcxt7f5rbrwy9r0000gn/T/ipykernel_82087/1325447683.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = 'lower right')

ax.text(10, 95, "This value is important!")
fig.show()
# Out:
# /var/folders/jx/71mqbyqd6wgcxt7f5rbrwy9r0000gn/T/ipykernel_82087/1963374730.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = 'lower right')

ax.text(10, 95, "This value is important!",
    ha = 'left',
    color = 'red',
    size = 20)
fig.show()
# Out:
# /var/folders/jx/71mqbyqd6wgcxt7f5rbrwy9r0000gn/T/ipykernel_82087/1851767157.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])

ax.text(1,5,".Data:(1,5)",transform=ax.transData)
ax.text(0.5,0.1,".Axes:(0.5,0.1)",transform=ax.transAxes)
ax.text(0.2,0.2,".Figure:(0.2,0.2)",transform=fig.transFigure)
# Out:
# Text(0.2, 0.2, '.Figure:(0.2,0.2)')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.annotate('This is important!', xy=(10, 95), xytext=(15, 94),
          arrowprops=dict(facecolor='black'))
fig.show()
16
# Out:
# /var/folders/jx/71mqbyqd6wgcxt7f5rbrwy9r0000gn/T/ipykernel_82087/915035336.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# 16

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.annotate('This is important!', xy=(10, 95), xytext=(15, 94),
          arrowprops=dict(arrowstyle='wedge',color='hotpink'))
fig.show()
# Out:
# /var/folders/jx/71mqbyqd6wgcxt7f5rbrwy9r0000gn/T/ipykernel_82087/1202279700.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
